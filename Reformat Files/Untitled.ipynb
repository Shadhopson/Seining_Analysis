# %%
import pandas as pd

# %%
fish_df = pd.read_csv('deleteme.csv')

# %%
fish_df
# Out:
#      Unnamed: 0                           Date                          Time  \
# 0             3   Saturday, September 13, 2008                           NaN
# 1             4   Saturday, September 13, 2008                           NaN
# 2             5   Saturday, September 13, 2008                           NaN
# 3             6   Saturday, September 13, 2008                           NaN
# 4             7   Saturday, September 13, 2008                           NaN
# 5             8   Saturday, September 13, 2008                           NaN
# 6             9   Saturday, September 13, 2008                           NaN
# 7            10   Saturday, September 13, 2008                           NaN
# 8            11   Saturday, September 13, 2008                           NaN
# 9            12   Saturday, September 13, 2008                           NaN
# 10           13   Saturday, September 13, 2008                           NaN
# ...

# %%
fish_df.groupby(['Date','Salinity']).sum()
# Out:
#                                                                           Unnamed: 0
# Date                            Salinity
# 07/01/16                        22 ppt                                           138
# 07/06/17                        21                                               452
# 07/13/16                        27 ppt                                           147
# 07/15/17 CITY OF WATER DAY      26                                               959
# 08/05/17 GREAT FISH COUNT       22                                              1695
# 10/15/2015                      30                                               616
# 10/7/17                         20 ppt                                           606
# 5/10/2014                       Not taken                                          3
# 5/26/2016                       35 ppt                                             0
# 5/30/2015                       22                                                 6
# ...
