# %%
import pandas as pd
import dateutil.parser
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('Created CSVs/all_seins_all_data_standard_dates.csv')

# %%
df['Date'] =  [dateutil.parser.parse(date) for date in list(df['Date'])]

# %%
sal_df = df[['Date', 'Salinity']]

# %%
sal_df = sal_df.dropna()

# %%
sal_df = sal_df[sal_df.Salinity.str.contains(r'\d') == True]

# %%
sal_df = sal_df.drop_duplicates()

# %%
import re

# %%
salinity = []
for sal in sal_df['Salinity']:
    first_num  = re.search(r'\d+', sal).group()
    salinity.append(first_num)

# %%
sal_df['Salinity'] = [int(x) for x in salinity]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
sal_df = sal_df.set_index('Date')

# %%
sal_df = sal_df[sal_df['Salinity'] > 1]

# %%
plt.figure(figsize=(10,5))
plt.title('Salinity Over Time')
plt.ylabel('Salinity in PPT')
plt.xlabel('Date')
plt.plot(sal_df)
plt.savefig('Graphs/Salinity_Graph')

# %%
sal_df.index
# Out:
# DatetimeIndex(['2014-07-12', '2014-09-20', '2014-08-23', '2015-05-30',
#                '2015-06-09', '2015-06-11', '2015-06-14', '2015-07-10',
#                '2015-07-28', '2015-08-09', '2015-09-25', '2015-10-15',
#                '2016-05-26', '2016-05-31', '2016-06-01', '2016-06-04',
#                '2016-06-14', '2016-06-15', '2016-07-01', '2016-07-13',
#                '2016-07-16', '2016-07-28', '2016-07-29', '2016-09-19',
#                '2016-09-19', '2017-06-03', '2017-06-09', '2017-06-10',
#                '2017-06-18', '2017-07-06', '2017-07-15', '2017-07-19',
#                '2017-07-22', '2017-08-02', '2017-08-05', '2017-08-20',
#                '2017-09-17', '2017-10-07'],
#               dtype='datetime64[ns]', name=u'Date', freq=None)

# %%
sal_df['Date'] = sal_df.index

# %%
sal_df['Year'] =  [x.year for x in sal_df['Date']]

# %%
sal_by_year = sal_df.groupby('Year')

# %%
sal2014 = sal_by_year.get_group(2014)['Salinity']

# %%
sal2014 = sal2014.sort_index()

# %%
sal2015 = sal_by_year.get_group(2015)['Salinity']

# %%
sal2016 = sal_by_year.get_group(2016)['Salinity']

# %%
sal2017 = sal_by_year.get_group(2017)['Salinity']

# %%
plt.figure(figsize=(10,5))
plt.title('Salinity Over Time')
plt.ylabel('Salinity in PPT')
plt.xlabel('Date')
plt.plot(sal2014)
plt.plot(sal2015)
plt.plot(sal2016)
plt.plot(sal2017)
plt.savefig('Graphs/Salinity_Graph')

# %%
sal2014.index = [x.dayofyear for x in sal2014.index]
sal2015.index = [x.dayofyear for x in sal2015.index]
sal2016.index = [x.dayofyear for x in sal2016.index]
sal2017.index = [x.dayofyear for x in sal2017.index]

# %%
plt.figure(figsize=(10,5))
plt.title('Salinity By Day Of The Year')
plt.ylabel('Salinity in PPT')
plt.xlabel('Date')
plt.plot(sal2014)
plt.plot(sal2015)
plt.plot(sal2016)
plt.plot(sal2017)
plt.legend(['2014', '2015', '2016', '2017'], loc='upper right')
plt.savefig('Graphs/Salinity_Graph_Year_Comparison')

# %%
conditions = df[['Date','DO', 'pH', 'Salinity', 'Turbidity', 'Water Temp:', 'Weather & Air Temp:']].drop_duplicates()

# %%
import numpy as np

# %%
def fix_ph(pH_li):
    pH_list  = []
    pH_li = pH_li.fillna('')
    pH_lists  = [re.findall('\d+\.*', x ) for x in pH_li]

    for pH in pH_lists:
        if len(pH) == 0:
            pH_list.append(np.NaN)
        elif len(pH) ==  1:
            pH_list.append(pH[0])
            #print pH[0]
        elif pH[0][-1] == '.':
            pH_list.append(pH[0]+pH[1])
            #print pH[0]+pH[1]
        else:
            pH_list.append(pH[0])
            #print 'bad',pH[1], pH
    #pHCompare['pH'] = pH_list
    return [float(x) for x in pH_list]

# %%
conditions['pH'] = fix_ph(conditions['pH'])

# %%
def fix_water_temp(h20_temp_list):
    water_temp_list = []
    h20_temp_list = h20_temp_list.fillna('')
    h20_temp_list  = [re.findall('\d+\.*', x ) for x in h20_temp_list]
    for temp in h20_temp_list:
        #print temp
        if len(temp) == 0:
            water_temp_list.append(np.NaN)
        elif len(temp) ==  1:
            if int(temp[0]) < 30:
                new_temp = int(temp[0]) * 9.0/5 + 32
                water_temp_list.append(str(new_temp))
            else:
                water_temp_list.append(temp[0])
            #print pH[0]
        elif temp[0][-1] == '.':
            water_temp_list.append(temp[0]+temp[1])
            #print pH[0]+pH[1]
        else:
            water_temp_list.append(temp[0])
    
    return [float(x) for x in water_temp_list]

# %%
conditions['Water Temp:'] = fix_water_temp(conditions['Water Temp:'])

# %%
def clean_salinity(sal_list):
    salinity = []
    for sal in sal_list:
        if sal != sal:
            salinity.append(sal)
        elif any(char.isdigit() for char in sal) == False:
            salinity.append(np.NAN)
        else:
            first_num  = re.search(r'\d+', sal).group()
            salinity.append(first_num)
    return [float(x) for x in salinity]

# %%
conditions['Salinity'] = clean_salinity(conditions['Salinity'])

# %%
temp_sal = conditions[['Water Temp:', 'Salinity']].dropna().drop_duplicates()

# %%
temp_sal['Water Temp:']= [float(x) for x in temp_sal['Water Temp:']]
temp_sal['Salinity']= [float(x) for x in temp_sal['Salinity']]

# %%
plt.scatter(temp_sal['Water Temp:'], temp_sal['Salinity'])

# %%
sns.regplot(temp_sal['Water Temp:'], temp_sal['Salinity'])

# %%
def clean_DO(DO_list):
    cleaned_list = []
    DO_list = DO_list.fillna('')
    DO_list  = [re.findall('\d+\.*', x ) for x in DO_list]

    for DO in DO_list:
        if len(DO) == 0:
            cleaned_list.append(np.NaN)
        else:
            cleaned_list.append(int(DO[0]))
       
    return cleaned_list

# %%
conditions['DO'] = clean_DO(conditions['DO'])

# %%
sns.regplot(conditions['Water Temp:'], conditions['DO'])

# %%
sns.regplot(conditions['Water Temp:'], conditions['pH'])

# %%
conditions.corr()
# Out:
#                    DO        pH  Salinity  Water Temp:
# DO           1.000000  0.163730 -0.013284    -0.243434
# pH           0.163730  1.000000 -0.072375     0.340480
# Salinity    -0.013284 -0.072375  1.000000    -0.072051
# Water Temp: -0.243434  0.340480 -0.072051     1.000000

# %%
conditions
# Out:
#           Date   DO    pH  Salinity        Turbidity  Water Temp:  \
# 0   2008-09-13  NaN   NaN       NaN              NaN          NaN
# 17  2009-06-20  NaN   NaN       NaN              NaN          NaN
# 29  2009-09-23  NaN   NaN       NaN              NaN          NaN
# 34  2010-06-12  NaN   NaN       NaN              NaN          NaN
# 43  2010-06-26  NaN   NaN       NaN              NaN          NaN
# 48  2010-07-07  NaN   NaN       NaN              NaN          NaN
# 50  2010-07-08  NaN   NaN       NaN              NaN          NaN
# 57  2010-07-09  NaN   NaN       NaN              NaN          NaN
# 68  2010-07-10  NaN   NaN       NaN              NaN          NaN
# 78  2010-07-20  NaN   NaN       NaN              NaN          NaN
# 87  2010-07-21  NaN   NaN       NaN              NaN          NaN
# 100 2010-07-22  NaN   NaN       NaN              NaN          NaN
# 113 2010-07-24  NaN   NaN       NaN              NaN          NaN
# 124 2010-08-10  NaN   NaN       NaN              NaN          NaN
# 133 2010-09-18  NaN   NaN       NaN              NaN          NaN
# 142 2010-09-21  NaN   NaN       NaN              NaN          NaN
# 151 2010-10-14  NaN   NaN       NaN              NaN          NaN
# 152 2018-10-14  NaN   NaN       NaN              NaN          NaN
# 157 2011-05-10  NaN   NaN       NaN              NaN          NaN
# 163 2011-05-14  NaN   NaN       NaN              NaN          NaN
# 174 2011-05-20  NaN   NaN       NaN              NaN          NaN
# 181 2011-05-28  NaN   NaN       NaN              NaN          NaN
# 187 2011-06-11  NaN   NaN       NaN              NaN          NaN
# 195 2011-06-14  NaN   NaN       NaN              NaN          NaN
# 206 2011-06-26  NaN   NaN       NaN              NaN          NaN
# 215 2011-07-10  NaN   NaN       NaN              NaN          NaN
# 227 2011-07-11  NaN   NaN       NaN              NaN          NaN
# 231 2011-07-12  NaN   NaN       NaN              NaN          NaN
# 238 2011-07-13  NaN   NaN       NaN              NaN          NaN
# 244 2011-08-02  NaN   NaN       NaN              NaN          NaN
# ..         ...  ...   ...       ...              ...          ...
# 600 2016-06-01  4.0  7.00      24.0              NaN         70.0
# 612 2016-06-04  4.0  7.00      22.0              NaN         79.0
# 626 2016-06-14  4.0  7.00      22.0              NaN         67.0
# 629 2016-06-15  NaN   NaN      29.0              NaN         63.0
# 635 2016-07-01  4.0  7.00      22.0              NaN         73.0
# 638 2016-07-13  NaN   NaN      27.0              NaN         74.0
# 641 2016-07-16  4.0  7.00      29.0              NaN         72.0
# 649 2016-07-28  4.0   NaN      28.0              NaN         74.0
# 656 2016-07-29  NaN   NaN      28.0              NaN         75.0
# 665 2016-08-12  NaN   NaN       NaN              NaN          NaN
# 675 2016-08-13  NaN   NaN       NaN              NaN          NaN
# 691 2016-09-18  NaN   NaN       NaN              NaN          NaN
# 710 2016-09-19  NaN   NaN      26.0              NaN         74.3
# 720 2016-09-19  NaN   NaN      25.0              NaN         74.0
# 739 2016-09-19  NaN   NaN       NaN              NaN          NaN
# 745 2016-09-25  4.0  7.00       NaN              NaN         65.0
# 755 2017-06-03  9.0   NaN      22.0  20.4 cm, 40 NTU         59.0
# 766 2017-06-09  4.0  7.00      23.0  Did not perform         66.0
# 775 2017-06-10  0.0  8.00      21.0  Did not perform         73.0
# 788 2017-06-18  4.0  7.00      27.0  Did not perform         70.0
# 796 2017-06-25  NaN   NaN       NaN  did not perform          NaN
# 802 2017-07-06  6.0  7.80      21.0   20 cm , 30 NTU         78.0
# 810 2017-07-15  6.0  7.50      26.0           20 NTU         75.0
# 824 2017-07-19  3.0  7.00      23.0          10 NTU?         82.0
# 838 2017-07-22  5.0  7.57      21.0              NaN         76.0
# 846 2017-08-02  6.0  7.70      22.0            37 cm         75.0
# 851 2017-08-05  6.0  7.50      22.0            35 cm         75.0
# 866 2017-08-20  4.0  7.31      21.0               24         75.0
# 883 2017-09-17  6.0  7.77      23.0               60         72.0
# 893 2017-10-07  6.0   NaN      20.0            0 JTU         72.0
#
#          Weather & Air Temp:
# 0                        NaN
# 17                       NaN
# 29                       NaN
# 34                       NaN
# 43                       NaN
# 48                       NaN
# 50                       NaN
# 57                       NaN
# 68                       NaN
# 78                       NaN
# 87                       NaN
# 100                      NaN
# 113                      NaN
# 124                      NaN
# 133                      NaN
# 142                      NaN
# 151                      NaN
# 152                      NaN
# 157                      NaN
# 163                      NaN
# 174                      NaN
# 181                      NaN
# 187                      NaN
# 195                      NaN
# 206                      NaN
# 215                      NaN
# 227                      NaN
# 231                      NaN
# 238                      NaN
# 244                      NaN
# ..                       ...
# 600                     77 F
# 612                     73 F
# 626                     82 F
# 629                     75 F
# 635                     84 F
# 638                     83 F
# 641                     87 F
# 649                     87 F
# 656                     85 F
# 665                     93 F
# 675                     96 F
# 691                     82 F
# 710                     76 F
# 720                     76 F
# 739                     76 F
# 745                     64 F
# 755   68 F @ 9:45 AM, Cloudy
# 766  90 F @ 3PM, 81 F @ 5 PM
# 775                     75 F
# 788              77 F/ Sunny
# 796    80 F/ Sun with clouds
# 802            84 F / Cloudy
# 810              85 F, Sunny
# 824                     76 F
# 838                88F Sunny
# 846       84 F Partly Cloudy
# 851                     73 F
# 866               75 F Sunny
# 883       75 F Partly Cloudy
# 893                   84.5 F
#
# [113 rows x 7 columns]

# %%
an_df = pd.read_csv('Created CSVs/Cleaned_For_Analysis_Compressed_By_Day.csv')

# %%
an_df.columns
# Out:
# Index([u'Unnamed: 0', u'Date', u'Time', u'Weather & Air Temp:', u'Water Temp:',
#        u'Corrected Water Temp:', u'pH', u'Corrected pH', u'DO',
#        u'Corrected DO', u'Turbidity', u'Salinity', u'Corrected Salinity',
#        u'Tide is moving', u'Tide Times', u'# Hauls', u'Corrected # Hauls',
#        u'Common Name', u'Corrected Common Name',
#        u'Grouped Corrected Common Name', u'Quantity', u'Corrected Quantity',
#        u'Scientific Name', u'Instructors/ Seine Staff:',
#        u'# student seiners (CLASSES ONLY)',
#        u'# of visitors (Public Seine ONLY)', u'# Brought to Ed Center',
#        u'NOTES FROM SEINEING SEASON:'],
#       dtype='object')

# %%
sal_temp = an_df[['Date', 'Corrected Water Temp:', 'Corrected Salinity']].dropna()

# %%
sal_temp.head()
# Out:
#           Date  Corrected Water Temp:  Corrected Salinity
# 67  2014-09-20                   71.6                22.0
# 68  2015-05-30                   68.0                22.0
# 71  2015-06-14                   68.0                33.0
# 72  2015-07-10                   78.8                36.0
# 75  2015-07-28                   73.4                29.0

# %%
import dateutil

# %%
sal_temp['Date'] = [dateutil.parser.parse(x) for x in sal_temp['Date']]

# %%
sal_temp['Year'] = [x.year for x in sal_temp['Date']]

# %%
sal_temp_2017 = sal_temp[sal_temp['Year'] == 2017]

# %%
plt.figure(figsize=(10,5))
plt.plot(sal_temp_2017['Date'],sal_temp_2017['Corrected Salinity'])
plt.plot(sal_temp_2017['Date'], sal_temp_2017['Corrected Water Temp:'])
plt.ylim(0,85)
# Out:
# (0, 85)

# %%
def two_scales(ax1, time, data1, data2, c1, c2):
    """

    Parameters
    ----------
    ax : axis
        Axis to put two scales on

    time : array-like
        x-axis values for both datasets

    data1: array-like
        Data for left hand scale

    data2 : array-like
        Data for right hand scale

    c1 : color
        Color for line 1

    c2 : color
        Color for line 2

    Returns
    -------
    ax : axis
        Original axis
    ax2 : axis
        New twin axis
    """
    ax2 = ax1.twinx()

    ax1.plot(time, data1, color=c1)
    ax1.set_xlabel('Date')
    ax1.set_ylabel('Salinity (ppt)')

    ax2.plot(time, data2, color=c2)
    ax2.set_ylabel('Water Temperature')
    return ax1, ax2

# %%
fig, ax = plt.subplots()
ax1, ax2 = two_scales(ax, sal_temp_2017['Date'], sal_temp_2017['Corrected Salinity'], sal_temp_2017['Corrected Water Temp:'], 'r', 'b')
ax1.grid(False)
ax2.grid(False)
ax1.figure.set_figwidth(10)
ax1.set_title('Salinity And Water Temperature Over Time')
def color_y_axis(ax, color):
    """Color your axes."""
    for t in ax.get_yticklabels():
        t.set_color(color)
    return None
color_y_axis(ax1, 'r')
color_y_axis(ax2, 'b')
plt.savefig('Graphs/SalinityAndWaterTempOverTime2017')
plt.show()

# %%
df_do = an_df[['Date', 'Corrected Water Temp:', 'Corrected DO']]

# %%
do_temp_2017 = df_do.dropna()

# %%
do_temp_2017['Year'] = [dateutil.parser.parse(x).year for x in do_temp_2017['Date']]
# Out:
# /home/shad/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
do_temp_2017 = do_temp_2017[do_temp_2017['Year'] == 2017]

# %%
do_temp_2017['Date'] = [dateutil.parser.parse(x) for x in do_temp_2017['Date']]

# %%
fig, ax = plt.subplots()
ax1, ax2 = two_scales(ax, do_temp_2017['Date'], do_temp_2017['Corrected DO'], do_temp_2017['Corrected Water Temp:'], 'r', 'b')
ax1.grid(False)
ax2.grid(False)
ax1.set_ylabel('DO')
ax1.figure.set_figwidth(10)
ax1.set_title('DO And Water Temperature Over Time')
def color_y_axis(ax, color):
    """Color your axes."""
    for t in ax.get_yticklabels():
        t.set_color(color)
    return None
color_y_axis(ax1, 'r')
color_y_axis(ax2, 'b')
plt.savefig('Graphs/DOAndWaterTempOverTime2017')
plt.show()
